# %%
import pandas as pd 
data = pd.read_csv('강원도 춘천시_관광지 및 상권 정밀 위치기반 이용자 실태 현황_20211221.csv', encoding='cp949')

# %%
df = data[data['읍면동'].isin(['효자동','석사동','동면 만천리','퇴계동','조양동','요선동','중앙로2가'])]

# %%
df = data[data['읍면동'].isin(['효자동'])]

# %%
# 상호명별 이용자수 합계 구하기
usage_sum = df.groupby('상호명')['이용자수'].sum()

# 상호명별 등장 횟수 구하기
count_by_name = df['상호명'].value_counts()

# 이용자수 합계를 등장 횟수로 나누어 평균 구하기
average_usage = usage_sum / count_by_name

# 평균 이용자수를 데이터프레임에 추가
df['평균이용자수'] = df['상호명'].map(average_usage)

# 중복된 상호명 제거
df.drop_duplicates(subset='상호명', inplace=True)

print(df)
# Out:
#               상호명          날짜     업종         위도          경도  시도  시군구  읍면동  \
# 5             짝모텔  2021-07-19   숙박시설  37.876267  127.734751  강원  춘천시  효자동
# 24          구철회내과  2021-07-19    병의원  37.876094  127.735321  강원  춘천시  효자동
# 28      야베스선교 갤러리  2021-07-19   종교시설  37.875434  127.738142  강원  춘천시  효자동
# 38          신낙지마루  2021-07-19    음식점  37.874758  127.743333  강원  춘천시  효자동
# 39            물안개  2021-07-19  호프/맥주  37.869976  127.725716  강원  춘천시  효자동
# ...           ...         ...    ...        ...         ...  ..  ...  ...
# 8035       첼로가요주점  2021-07-19   유흥주점  37.876327  127.734566  강원  춘천시  효자동
# 8043          일프로  2021-07-19   유흥주점  37.876261  127.734715  강원  춘천시  효자동
# 8047           두향  2021-07-19    음식점  37.868122  127.730379  강원  춘천시  효자동
# 8066      나래관 잡카페  2021-07-19   공공시설  37.870018  127.744935  강원  춘천시  효자동
# 361780     윤일 닭갈비  2021-09-01    음식점  37.863295  127.735522  강원  춘천시  효자동
#
#         이용자수   남성비율   여성비율  10대비율  20대비율  30대비율  40대비율  50대이상비율      데이터기준일  \
# 5        236  59.00  41.00   7.84  22.45  10.09  29.91    29.71  2021-12-21
# 24       236  51.98  48.02  13.56  21.12  22.09  22.55    20.68  2021-12-21
# 28        79  51.24  48.76  13.56  21.08  22.64  23.03    19.69  2021-12-21
# 38       100  35.41  64.59  13.08  20.58  23.48  21.11    21.75  2021-12-21
# 39       630  55.16  44.84   8.84  16.27  24.01  25.99    24.89  2021-12-21
# ...      ...    ...    ...    ...    ...    ...    ...      ...         ...
# 8035      79  61.90  38.10   4.15  14.81  31.89  35.40    13.75  2021-12-21
# 8043     315  61.65  38.35   4.62  13.57  31.28  37.45    13.08  2021-12-21
# 8047     945  29.15  70.85  12.02   0.40   0.84   3.20    83.54  2021-12-21
# 8066      84  52.49  47.51  13.75  21.14  21.86  21.14    22.11  2021-12-21
# 361780    75  57.93  42.07  12.15  19.89  22.70  24.31    20.95  2021-12-21
#
#             평균이용자수
# 5       143.893443
# 24      137.221311
# 28       93.286885
# 38      105.696721
# 39      255.713115
# ...            ...
# 8035    111.852459
# 8043    193.434426
# 8047    752.278689
# 8066     86.975410
# 361780  131.128205
#
# [601 rows x 18 columns]
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11688\2401372191.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['평균이용자수'] = df['상호명'].map(average_usage)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11688\2401372191.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset='상호명', inplace=True)

# %%
df
# Out:
#               상호명          날짜     업종         위도          경도  시도  시군구  읍면동  \
# 5             짝모텔  2021-07-19   숙박시설  37.876267  127.734751  강원  춘천시  효자동
# 24          구철회내과  2021-07-19    병의원  37.876094  127.735321  강원  춘천시  효자동
# 28      야베스선교 갤러리  2021-07-19   종교시설  37.875434  127.738142  강원  춘천시  효자동
# 38          신낙지마루  2021-07-19    음식점  37.874758  127.743333  강원  춘천시  효자동
# 39            물안개  2021-07-19  호프/맥주  37.869976  127.725716  강원  춘천시  효자동
# ...           ...         ...    ...        ...         ...  ..  ...  ...
# 8035       첼로가요주점  2021-07-19   유흥주점  37.876327  127.734566  강원  춘천시  효자동
# 8043          일프로  2021-07-19   유흥주점  37.876261  127.734715  강원  춘천시  효자동
# 8047           두향  2021-07-19    음식점  37.868122  127.730379  강원  춘천시  효자동
# 8066      나래관 잡카페  2021-07-19   공공시설  37.870018  127.744935  강원  춘천시  효자동
# 361780     윤일 닭갈비  2021-09-01    음식점  37.863295  127.735522  강원  춘천시  효자동
#
#         이용자수   남성비율   여성비율  10대비율  20대비율  30대비율  40대비율  50대이상비율      데이터기준일  \
# 5        236  59.00  41.00   7.84  22.45  10.09  29.91    29.71  2021-12-21
# 24       236  51.98  48.02  13.56  21.12  22.09  22.55    20.68  2021-12-21
# 28        79  51.24  48.76  13.56  21.08  22.64  23.03    19.69  2021-12-21
# 38       100  35.41  64.59  13.08  20.58  23.48  21.11    21.75  2021-12-21
# 39       630  55.16  44.84   8.84  16.27  24.01  25.99    24.89  2021-12-21
# ...      ...    ...    ...    ...    ...    ...    ...      ...         ...
# 8035      79  61.90  38.10   4.15  14.81  31.89  35.40    13.75  2021-12-21
# 8043     315  61.65  38.35   4.62  13.57  31.28  37.45    13.08  2021-12-21
# 8047     945  29.15  70.85  12.02   0.40   0.84   3.20    83.54  2021-12-21
# 8066      84  52.49  47.51  13.75  21.14  21.86  21.14    22.11  2021-12-21
# 361780    75  57.93  42.07  12.15  19.89  22.70  24.31    20.95  2021-12-21
#
#             평균이용자수
# 5       143.893443
# 24      137.221311
# 28       93.286885
# 38      105.696721
# 39      255.713115
# ...            ...
# 8035    111.852459
# 8043    193.434426
# 8047    752.278689
# 8066     86.975410
# 361780  131.128205
#
# [601 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
import matplotlib.pyplot as plt
# 업종별 개수 집계
업종별_개수 = df['업종'].value_counts()

# 막대 그래프 그리기
plt.figure(figsize=(10, 6))
업종별_개수.plot(kind='bar', color='skyblue')
plt.title('업종별 개수')
plt.xlabel('업종')
plt.ylabel('개수')
plt.xticks(rotation=45)  # x축 라벨 회전
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
평균이용자수_업종별 = df.groupby('업종')['평균이용자수'].mean().sort_values(ascending=False)

# 막대 그래프 그리기
plt.figure(figsize=(10, 6))
평균이용자수_업종별.plot(kind='bar', color='skyblue')
plt.title('평균 이용자수가 많은 업종')
plt.xlabel('업종')
plt.ylabel('평균 이용자수')
plt.xticks(rotation=45)  # x축 라벨 회전
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
업종별_개수 = df['업종'].value_counts()

# 업종별 평균 이용자수 계산
평균이용자수_업종별 = df.groupby('업종')['평균이용자수'].mean()

# 업종별 개수로 이용자수를 나누기
평균이용자수_업종별_정규화 = 평균이용자수_업종별 / 업종별_개수

# 막대 그래프 그리기
plt.figure(figsize=(10, 6))
평균이용자수_업종별_정규화.plot(kind='bar', color='skyblue')
plt.title('업종별 개수로 나눈 평균 이용자수')
plt.xlabel('업종')
plt.ylabel('평균 이용자수')
plt.xticks(rotation=45)  # x축 라벨 회전
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df_combined = df

# %%
df_combined
# Out:
#               상호명          날짜     업종         위도          경도  시도  시군구  읍면동  \
# 5             짝모텔  2021-07-19   숙박시설  37.876267  127.734751  강원  춘천시  효자동
# 24          구철회내과  2021-07-19    병의원  37.876094  127.735321  강원  춘천시  효자동
# 28      야베스선교 갤러리  2021-07-19   종교시설  37.875434  127.738142  강원  춘천시  효자동
# 38          신낙지마루  2021-07-19    음식점  37.874758  127.743333  강원  춘천시  효자동
# 39            물안개  2021-07-19  호프/맥주  37.869976  127.725716  강원  춘천시  효자동
# ...           ...         ...    ...        ...         ...  ..  ...  ...
# 8035       첼로가요주점  2021-07-19   유흥주점  37.876327  127.734566  강원  춘천시  효자동
# 8043          일프로  2021-07-19   유흥주점  37.876261  127.734715  강원  춘천시  효자동
# 8047           두향  2021-07-19    음식점  37.868122  127.730379  강원  춘천시  효자동
# 8066      나래관 잡카페  2021-07-19   공공시설  37.870018  127.744935  강원  춘천시  효자동
# 361780     윤일 닭갈비  2021-09-01    음식점  37.863295  127.735522  강원  춘천시  효자동
#
#         이용자수   남성비율   여성비율  10대비율  20대비율  30대비율  40대비율  50대이상비율      데이터기준일  \
# 5        236  59.00  41.00   7.84  22.45  10.09  29.91    29.71  2021-12-21
# 24       236  51.98  48.02  13.56  21.12  22.09  22.55    20.68  2021-12-21
# 28        79  51.24  48.76  13.56  21.08  22.64  23.03    19.69  2021-12-21
# 38       100  35.41  64.59  13.08  20.58  23.48  21.11    21.75  2021-12-21
# 39       630  55.16  44.84   8.84  16.27  24.01  25.99    24.89  2021-12-21
# ...      ...    ...    ...    ...    ...    ...    ...      ...         ...
# 8035      79  61.90  38.10   4.15  14.81  31.89  35.40    13.75  2021-12-21
# 8043     315  61.65  38.35   4.62  13.57  31.28  37.45    13.08  2021-12-21
# 8047     945  29.15  70.85  12.02   0.40   0.84   3.20    83.54  2021-12-21
# 8066      84  52.49  47.51  13.75  21.14  21.86  21.14    22.11  2021-12-21
# 361780    75  57.93  42.07  12.15  19.89  22.70  24.31    20.95  2021-12-21
#
#             평균이용자수
# 5       143.893443
# 24      137.221311
# 28       93.286885
# 38      105.696721
# 39      255.713115
# ...            ...
# 8035    111.852459
# 8043    193.434426
# 8047    752.278689
# 8066     86.975410
# 361780  131.128205
#
# [601 rows x 18 columns]

# %%
import folium
from folium.plugins import MarkerCluster

# 첫 번째 데이터셋
map_center = [df['위도'].mean(), df['경도'].mean()]
mymap = folium.Map(location=map_center, zoom_start=10)

# 마커 클러스터링 추가
marker_cluster = MarkerCluster().add_to(mymap)

# 첫 번째 데이터셋의 마커 (기본 색상)
for index, row in df.iterrows():
    popup = folium.Popup(row['상호명'], parse_html=True)
    folium.Marker([row['위도'], row['경도']], popup=popup).add_to(marker_cluster)

# 지도를 표시
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad71ec176e5919531ac28a5eb94fe965 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad71ec176e5919531ac28a5eb94fe965&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad71ec176e5919531ac28a5eb94fe965 = L.map(
#                 &quot;map_ad71ec176e5919531ac28a5eb94fe965&quot;,
#                 {
#                     center: [37.87219147587355, 127.73677005158069],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13a7eee530da199c0a03ca93b375a5ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_13a7eee530da199c0a03ca93b375a5ac.addTo(map_ad71ec176e5919531ac28a5eb94fe965);
#
#
#             var marker_cluster_0cdacf303f1f489f7f8ebd36a4c4f885 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_c548e17fe0ba78d94c6838d84c6892f9 = L.marker(
#                 [37.876267, 127.734751],
#                 {}
#             ).addTo(marker_cluster_0cdacf303f1f489f7f8ebd36a4c4f885);
#
#
#         var popup_bf5ac93d0823264f84da4c7d6a126000 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eba76055980ac6347b98a42fc0da6e55 = $(`&lt;div id=&quot;html_eba76055980ac6347b98a42fc0da6e55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;짝모텔&lt;/div&gt;`)[0];
#                 popup_bf5ac93d0823264f84da4c7d6a126000.setContent(html_eba76055980ac6347b98a42fc0da6e55);
#
#
#
#         marker_c548e17fe0ba78d94c6838d84c6892f9.bindPopup(popup_bf5ac93d0823264f84da4c7d6a126000)
#         ;
#
#
#
#
#             var marker_ce46c0f47b67c66b93fae40eeaa65fd9 = L.marker(
#                 [37.876094, 127.735321],
#                 {}
#             ).addTo(marker_cluster_0cdacf303f1f489f7f8ebd36a4c4f885);
#
#
#         var popup_a211ccd95ae2b2417c02f1775e7c9e35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31ba2aa744ebe7fdf1451912bdc605f9 = $(`&lt;div id=&quot;html_31ba2aa744ebe7fdf1451912bdc605f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;구철회내과&lt;/div&gt;`)[0];
#                 popup_a211ccd95ae2b2417c02f1775e7c9e35.setContent(html_31ba2aa744ebe7fdf1451912bdc605f9);
#
#
#
#         marker_ce46c0f47b67c66b93fae40eeaa65fd9.bindPopup(popup_a211ccd95ae2b2417c02f1775e7c9e35)
#         ;
#
#
#
#
#             var marker_39fa86879f89b4576b9b4c9c8361a31c = L.marker(
#                 [37.875434, 127.738142],
#                 {}
#             ).addTo(marker_cluster_0cdacf303f1f489f7f8ebd36a4c4f885);
#
#
#         var popup_e1d7dae4592010a2c8eaaa66875870de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fabf8d265416d107321edd904b5cf300 = $(`&lt;div id=&quot;html_fabf8d265416d107321edd904b5cf300&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;야베스선교 갤러리&lt;/div&gt;`)[0];
#                 popup_e1d7dae4592010a2c8eaaa66875870de.setContent(html_fabf8d265416d107321edd904b5cf300);
#
#
#
#         marker_39fa86879f89b4576b9b4c9c8361a31c.bindPopup(popup_e1d7dae4592010a2c8eaaa66875870de)
#         ;
#
#
#
#
#             var marker_fbcfddc9b983b71addf26181d6ad85ff = L.marker(
#                 [37.874758, 127.743333],
#                 {}
#             ).addTo(marker_cluster_0cdacf303f1f489f7f8ebd36a4c4f885);
#
#
#         var popup_de987e19515f964f04c1bb3c3c1b2d47 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8fd89fc8bd17723645bb25d881c4185d = $(`&lt;div id=&quot;html_8fd89fc8bd17723645bb25d881c4185d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신낙지마루&lt;/div&gt;`)[0];
#                 popup_de987e19515f964f04c1bb3c3c1b2d47.setContent(html_8fd89fc8bd17723645bb25d881c4185d);
#
#
#
#         marker_fbcfddc9b983b71addf26181d6ad85ff.bindPopup(popup_de987e19515f964f04c1bb3c3c1b2d47)
#         ;
#
#
#
#
#             var marker_76dc80287ed3193d4be8f2350e7fe030 = L.marker(
#                 [37.869976, 127.725716],
#                 {}
#             ).addTo(marker_cluster_0cdacf303f1f489f7f8ebd36a4c4f885);
#
#
#         var popup_a8e6667118e3b3db0846c5f07e74421d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bad3f

# %%
from sklearn.cluster import KMeans
import folium
from folium.plugins import MarkerCluster
# K-means 클러스터링 수행 (가중치 적용)
k = 5  # 클러스터의 수
coordinates = df_combined[['위도', '경도']]
weights = df_combined['평균이용자수']

kmeans = KMeans(n_clusters=k, random_state=0).fit(coordinates, sample_weight=weights)
df_combined['클러스터'] = kmeans.labels_

# 가중치 적용된 클러스터 중심 좌표
centers = kmeans.cluster_centers_
# Folium 지도 생성
map_center = [df_combined['위도'].mean(), df_combined['경도'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# 마커 클러스터링 추가
marker_cluster = MarkerCluster().add_to(mymap)

# 정류장 위치 표시 및 클러스터링
for idx, row in df_combined.iterrows():
    popup = folium.Popup(f"{row['상호명']} (합계: {row['평균이용자수']})", parse_html=True)
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=popup,
        tooltip=row['상호명'],
      
    ).add_to(marker_cluster)

# 클러스터 중심 위치 표시
for center in centers:
    folium.Marker(
        location=[center[0], center[1]],
        popup="가중치 적용된 클러스터 중심",
        icon=folium.Icon(color='black', icon='info-sign')
    ).add_to(mymap)

# Jupyter Notebook 환경에서 지도 출력
mymap
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11688\2538616159.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined['클러스터'] = kmeans.labels_
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c9ccadc29e9feda8858168e86aabd05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c9ccadc29e9feda8858168e86aabd05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c9ccadc29e9feda8858168e86aabd05 = L.map(
#                 &quot;map_2c9ccadc29e9feda8858168e86aabd05&quot;,
#                 {
#                     center: [37.87219147587355, 127.73677005158069],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d95421f18d92558e2930c5986c68da9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3d95421f18d92558e2930c5986c68da9.addTo(map_2c9ccadc29e9feda8858168e86aabd05);
#
#
#             var marker_cluster_f5a31b008827b1f0a0d9fba23932b99d = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_cdcacd5aac6072da2c9db6a6443b4f2c = L.marker(
#                 [37.876267, 127.734751],
#                 {}
#             ).addTo(marker_cluster_f5a31b008827b1f0a0d9fba23932b99d);
#
#
#         var popup_6cfa8cabf8dedcb2a77ac49d6dcd3282 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a63ce3637f138691814a7f17e298754 = $(`&lt;div id=&quot;html_7a63ce3637f138691814a7f17e298754&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;짝모텔 (합계: 143.89344262295083)&lt;/div&gt;`)[0];
#                 popup_6cfa8cabf8dedcb2a77ac49d6dcd3282.setContent(html_7a63ce3637f138691814a7f17e298754);
#
#
#
#         marker_cdcacd5aac6072da2c9db6a6443b4f2c.bindPopup(popup_6cfa8cabf8dedcb2a77ac49d6dcd3282)
#         ;
#
#
#
#
#             marker_cdcacd5aac6072da2c9db6a6443b4f2c.bindTooltip(
#                 `&lt;div&gt;
#                      짝모텔
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_769f3d1d832ad1f46ec10de88edd7ff0 = L.marker(
#                 [37.876094, 127.735321],
#                 {}
#             ).addTo(marker_cluster_f5a31b008827b1f0a0d9fba23932b99d);
#
#
#         var popup_d2e53622b64914ba138b064e5060832c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2962eefed9680da9f71fe1b9950071f = $(`&lt;div id=&quot;html_a2962eefed9680da9f71fe1b9950071f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;구철회내과 (합계: 137.22131147540983)&lt;/div&gt;`)[0];
#                 popup_d2e53622b64914ba138b064e5060832c.setContent(html_a2962eefed9680da9f71fe1b9950071f);
#
#
#
#         marker_769f3d1d832ad1f46ec10de88edd7ff0.bindPopup(popup_d2e53622b64914ba138b064e5060832c)
#         ;
#
#
#
#
#             marker_769f3d1d832ad1f46ec10de88edd7ff0.bindTooltip(
#                 `&lt;div&gt;
#                      구철회내과
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9575b5eb13b43233388edf9bef1b8cdb = L.marker(
#                 [37.875434, 127.738142],
#                 {}
#             ).addTo(marker_cluster_f5a31b008827b1f0a0d9fba23932b99d);
#
#
#         var popup_ca08b9282b0be99de8a77b20b8b563af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6014547ca1d8861dc06e12dafc90006 = $(`&lt;div id=&quot;html_e6014547ca1d8861dc06e12dafc90006&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;야베스선교 갤러리 (합계: 93.28688524590164)&lt;/div&gt;`)[0];
#                 popup_ca08b9282b0be99de8a77b20b8b563af.setContent(html_e6014547ca1d8861dc06e12dafc90006);
#
#
#
#         marker_9575b5eb13b43233388edf9bef1b8cdb.bindPopup(popup_ca08b9282b0be99de8a77b20b8b563af)
#         ;
#
#
#
#
#             marker_9575b5eb13b43233388edf9bef1b8cdb.bindTooltip(
#                 `&lt;div&gt;
#                      야베스선교 갤러리
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1b778ea97f0d2bbebcdaaefff84a9c9f = L.marker(
#                 [37.874758, 127.743333],
#                 {}
#             ).addTo(marker_cluster_f5a31b008827b1f0a0d9fba23932b99d);
#
#
#         var popup_e15e6ede077fad69458aa37542b24cc7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a571b2b1459732d4f4dff105053b065 = $(`&lt;div id=&

# %%
from sklearn.cluster import KMeans
import folium
from folium.plugins import MarkerCluster

# K-means 클러스터링 수행 (가중치 적용)
k = 4  # 클러스터의 수
coordinates = df_combined[['위도', '경도']]
weights = df_combined['평균이용자수']

kmeans = KMeans(n_clusters=k, random_state=0).fit(coordinates, sample_weight=weights)
df_combined['클러스터'] = kmeans.labels_

# 가중치 적용된 클러스터 중심 좌표
centers = kmeans.cluster_centers_

# Folium 지도 생성
map_center = [df_combined['위도'].mean(), df_combined['경도'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# 마커 클러스터링 추가
marker_cluster = MarkerCluster().add_to(mymap)

# 색상을 클러스터별로 지정
cluster_colors = {1: 'green', 2: 'red', 3: 'purple'}

# 정류장 위치 표시 및 클러스터링

# 클러스터 중심 위치 표시
for center in centers:
    folium.Marker(
        location=[center[0], center[1]],
        popup="가중치 적용된 클러스터 중심",
        icon=folium.Icon(color='black', icon='info-sign')
    ).add_to(mymap)

# Jupyter Notebook 환경에서 지도 출력
mymap
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11688\3069677183.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined['클러스터'] = kmeans.labels_
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5024cfc73ef1fe2a736901020ee4c6f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5024cfc73ef1fe2a736901020ee4c6f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5024cfc73ef1fe2a736901020ee4c6f8 = L.map(
#                 &quot;map_5024cfc73ef1fe2a736901020ee4c6f8&quot;,
#                 {
#                     center: [37.87219147587355, 127.73677005158069],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed287da42dfe506e9d97afd26cae1dbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ed287da42dfe506e9d97afd26cae1dbc.addTo(map_5024cfc73ef1fe2a736901020ee4c6f8);
#
#
#             var marker_cluster_7142c3ba738b9fa5838de95cf2df3ab8 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_7142c3ba738b9fa5838de95cf2df3ab8.addTo(map_5024cfc73ef1fe2a736901020ee4c6f8);
#
#
#             var marker_fc1ea27899a725399364529aaeecf393 = L.marker(
#                 [37.869980827946165, 127.72886894913997],
#                 {}
#             ).addTo(map_5024cfc73ef1fe2a736901020ee4c6f8);
#
#
#             var icon_4052f443849cdcbeedb474c1ab47c72f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fc1ea27899a725399364529aaeecf393.setIcon(icon_4052f443849cdcbeedb474c1ab47c72f);
#
#
#         var popup_563498b4a28fb597ff7c939665d45eb7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e07dcaff84b22f83b66eac07292326fb = $(`&lt;div id=&quot;html_e07dcaff84b22f83b66eac07292326fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가중치 적용된 클러스터 중심&lt;/div&gt;`)[0];
#                 popup_563498b4a28fb597ff7c939665d45eb7.setContent(html_e07dcaff84b22f83b66eac07292326fb);
#
#
#
#         marker_fc1ea27899a725399364529aaeecf393.bindPopup(popup_563498b4a28fb597ff7c939665d45eb7)
#         ;
#
#
#
#
#             var marker_6b907bfc026c15cfbed7aa38d57befd9 = L.marker(
#                 [37.87593180659868, 127.73722463539664],
#                 {}
#             ).addTo(map_5024cfc73ef1fe2a736901020ee4c6f8);
#
#
#             var icon_6611ebc562457e4322371bc2e63df5e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b907bfc026c15cfbed7aa38d57befd9.setIcon(icon_6611ebc562457e4322371bc2e63df5e0);
#
#
#         var popup_d6521b4b29b8b28a9269ef48c156bd2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a56f8cacbf1e706587b2fa7c5b85434 = $(`&lt;div id=&quot;html_5a56f8cacbf1e706587b2fa7c5b85434&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가중치 적용된 클러스터 중심&lt;/div&gt;`)[0];
#                 popup_d6521b4b29b8b28a9269ef48c156bd2c.setContent(html_5a56f8cacbf1e706587b2fa7c5b85434);
#
#
#
#         marker_6b907bfc026c15cfbed7aa38d57befd9.bindPopup(popup_d6521b4b29b8b28a9269ef48c156bd2c)
#         ;
#
#
#
#
#             var marker_f3e49a30afbef860680a9fb25803ea00 = L.marker(
#                 [37.873125148571724, 127.74290587777038],
#                 {}
#             ).addTo(map_5024cfc73ef1fe2a736901020ee4c6f8);
#
#
#             var icon_7ff6440157f4fb80fd407e9af5c2290b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3e49a30afbef860680a9fb25803ea00.setIcon(icon_7ff6440157f4fb80fd407e9af5c2290b);
#
#
#         var popup_8cc5da1426da184b5f3086a20e479c66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2dcd9df088b934a0ff1fa3f304805895 = $(`&lt;div id=&quot;html_2dcd9df088b934a0ff1fa3f304805895&quot; style=

# %%
centesrs_man
# Out:
# array([[ 37.86998083, 127.72886895],
#        [ 37.87593181, 127.73722464],
#        [ 37.87312515, 127.74290588],
#        [ 37.86547379, 127.73411059]])

# %%
centesrs_man = centers

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# 클러스터 개수 후보
max_k = 10
sse = []

# K-means 클러스터링 수행 및 SSE 계산
for k in range(1, max_k + 1):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(coordinates, sample_weight=weights)
    sse.append(kmeans.inertia_)

# SSE 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(range(1, max_k + 1), sse, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.title('Elbow Method')
plt.xticks(range(1, max_k + 1))
plt.grid(True)
plt.show()

# %%
#버스

# %%
import pandas as pd
df = pd.read_csv('chuncheon_villages.csv',encoding='cp949')

# %%
result = df[df['노선번호'].isin(['100', '100-1','101','200','200-1','300','400','1', '2','3','4','6','7','7-1','7-2','7-3','8','8-1','9','10','10-1','11','12','13','13-1','14','15','16','16-1',
                            '17','18'])]

# %%
df = result

# %%
filtered_df = df[df['주소'].str.contains('효자동')]

df_combined = filtered_df

# %%
df_combined
# Out:
#      노선번호     노선(ID)  정류장순서    정류장(ID)      정류장명         경도        위도  \
# 10      1  250000100     11  250001853    일성트루엘A  127.74822  37.87735
# 11      1  250000100     12  250002238    푸른언덕공원  127.74556  37.87622
# 12      1  250000100     13  250001750    강원대학병원  127.74295  37.87474
# 13      1  250000100     14  250001678  춘천청소년수련관  127.74109  37.87438
# 75      1  250000100     76  250001677  춘천청소년수련관  127.74071  37.87433
# ...   ...        ...    ...        ...       ...        ...       ...
# 3348  300  250030000     40  250026904  강원대중앙도서관  127.74430  37.87107
# 3349  300  250030000     41  250001748     강원대후문  127.74430  37.87292
# 3350  300  250030000     42  250001749    강원대학병원  127.74331  37.87484
# 3351  300  250030000     43  250002237    푸른언덕공원  127.74630  37.87627
# 3352  300  250030000     44  250001205     후평중학교  127.74843  37.87723
#
#           데이터기준일                                                 주소
# 10    2024-01-02           백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24280, 대한민국
# 11    2024-01-02   푸른언덕공원, 백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24290, 대한민국
# 12    2024-01-02   강원대학병원, 백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24295, 대한민국
# 13    2024-01-02              서부대성로, 효자동, 춘천시, 강원특별자치도, 24331, 대한민국
# 75    2024-01-02              서부대성로, 효자동, 춘천시, 강원특별자치도, 24331, 대한민국
# ...          ...                                                ...
# 3348  2024-01-02  강원대중앙도서관, 서부대성로, 효자동, 만천리, 춘천시, 강원특별자치도, 24341...
# 3349  2024-01-02  강원대후문, 서부대성로, 효자동, 만천리, 춘천시, 강원특별자치도, 24289, 대한민국
# 3350  2024-01-02           백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24289, 대한민국
# 3351  2024-01-02   푸른언덕공원, 백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24280, 대한민국
# 3352  2024-01-02           백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24280, 대한민국
#
# [77 rows x 9 columns]

# %%
df_combined = df_combined.drop_duplicates(subset=['정류장명'], keep='first')

# %%
df_combined
# Out:
#      노선번호     노선(ID)  정류장순서    정류장(ID)      정류장명         경도        위도  \
# 10      1  250000100     11  250001853    일성트루엘A  127.74822  37.87735
# 11      1  250000100     12  250002238    푸른언덕공원  127.74556  37.87622
# 12      1  250000100     13  250001750    강원대학병원  127.74295  37.87474
# 13      1  250000100     14  250001678  춘천청소년수련관  127.74109  37.87438
# 78      1  250000100     79  250001205     후평중학교  127.74843  37.87723
# 625     6  250000600     15  250026535    강원사대부고  127.74738  37.87188
# 626     6  250000600     16  250001748     강원대후문  127.74430  37.87292
# 1790   11  250001100    100  250002225    교대부설초교  127.73106  37.86976
# 3327  300  250030000     19  250026905    강원대백록관  127.74135  37.86861
# 3328  300  250030000     20  250026907     강원대정문  127.73783  37.86652
# 3330  300  250030000     22  250002240        법원  127.73291  37.86606
# 3348  300  250030000     40  250026904  강원대중앙도서관  127.74430  37.87107
#
#           데이터기준일                                                 주소
# 10    2024-01-02           백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24280, 대한민국
# 11    2024-01-02   푸른언덕공원, 백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24290, 대한민국
# 12    2024-01-02   강원대학병원, 백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24295, 대한민국
# 13    2024-01-02              서부대성로, 효자동, 춘천시, 강원특별자치도, 24331, 대한민국
# 78    2024-01-02           백령로, 효자동, 만천리, 춘천시, 강원특별자치도, 24280, 대한민국
# 625   2024-01-02  강원사대부고, 서부대성로, 효자동, 만천리, 춘천시, 강원특별자치도, 24286, ...
# 626   2024-01-02  강원대후문, 서부대성로, 효자동, 만천리, 춘천시, 강원특별자치도, 24289, 대한민국
# 1790  2024-01-02                소전길, 효자동, 춘천시, 강원특별자치도, 24338, 대한민국
# 3327  2024-01-02        강원대백록관, 백령로, 효자동, 춘천시, 강원특별자치도, 24341, 대한민국
# 3328  2024-01-02     강원대정문, 백령로25번길, 효자동, 춘천시, 강원특별자치도, 24342, 대한민국
# 3330  2024-01-02            법원, 남춘로, 효자동, 춘천시, 강원특별자치도, 24372, 대한민국
# 3348  2024-01-02  강원대중앙도서관, 서부대성로, 효자동, 만천리, 춘천시, 강원특별자치도, 24341...

# %%
import folium

# Folium 지도 생성
map_center = [df_combined['위도'].mean(), df_combined['경도'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)
# 다른 위치 정보 추가
for index, row in df_combined.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=row['정류장명'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(mymap)

# 지도 출력
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54149f2b3214795e5d0055345c7e6d7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54149f2b3214795e5d0055345c7e6d7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54149f2b3214795e5d0055345c7e6d7d = L.map(
#                 &quot;map_54149f2b3214795e5d0055345c7e6d7d&quot;,
#                 {
#                     center: [37.87222833333333, 127.74211500000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a20cd37a124db57b41a3a8ddf6eb5ee3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a20cd37a124db57b41a3a8ddf6eb5ee3.addTo(map_54149f2b3214795e5d0055345c7e6d7d);
#
#
#             var marker_56d24a8ba89626248f6c1f96008d09b2 = L.marker(
#                 [37.87735, 127.74822],
#                 {}
#             ).addTo(map_54149f2b3214795e5d0055345c7e6d7d);
#
#
#             var icon_468fb0af0e9ea572845cbd3811e9ced4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_56d24a8ba89626248f6c1f96008d09b2.setIcon(icon_468fb0af0e9ea572845cbd3811e9ced4);
#
#
#         var popup_d054ff8a250129d43d591840dd8b4494 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f66285fbafb21b0637a1e93ed347e0a = $(`&lt;div id=&quot;html_6f66285fbafb21b0637a1e93ed347e0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;일성트루엘A&lt;/div&gt;`)[0];
#                 popup_d054ff8a250129d43d591840dd8b4494.setContent(html_6f66285fbafb21b0637a1e93ed347e0a);
#
#
#
#         marker_56d24a8ba89626248f6c1f96008d09b2.bindPopup(popup_d054ff8a250129d43d591840dd8b4494)
#         ;
#
#
#
#
#             var marker_36530111c42242bd1443d4d2814e9ed9 = L.marker(
#                 [37.87622, 127.74556],
#                 {}
#             ).addTo(map_54149f2b3214795e5d0055345c7e6d7d);
#
#
#             var icon_e940e53861e9bf58d01b7e2c75b2f58a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_36530111c42242bd1443d4d2814e9ed9.setIcon(icon_e940e53861e9bf58d01b7e2c75b2f58a);
#
#
#         var popup_1eaf4b8c1f52ba5a0b704085fc30e234 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b11065c767775aa6818913dc805dcff = $(`&lt;div id=&quot;html_6b11065c767775aa6818913dc805dcff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;푸른언덕공원&lt;/div&gt;`)[0];
#                 popup_1eaf4b8c1f52ba5a0b704085fc30e234.setContent(html_6b11065c767775aa6818913dc805dcff);
#
#
#
#         marker_36530111c42242bd1443d4d2814e9ed9.bindPopup(popup_1eaf4b8c1f52ba5a0b704085fc30e234)
#         ;
#
#
#
#
#             var marker_d763dfc6822d6341d52e4ad480d23945 = L.marker(
#                 [37.87474, 127.74295],
#                 {}
#             ).addTo(map_54149f2b3214795e5d0055345c7e6d7d);
#
#
#             var icon_94d74c03778027e2141a3c8517680ba5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d763dfc6822d6341d52e4ad480d23945.setIcon(icon_94d74c03778027e2141a3c8517680ba5);
#
#
#         var popup_650c7b74c272495a6164912352931641 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d43b77c3e7f564169c5ac1a5ab708b2 = $(`&lt;div id=&quot;html_0d43b77c3e7f564169c5ac1a5ab708b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강원대학병원&lt;/div&gt;`)[0];
#                 popup_650c7b74c272495a6164912352931641.setContent(html_0d43b77c3e7f564169c5ac1a5ab708b2);
#
#
#
#         marker_d763dfc6822d6341d52e4ad480d23945.bindPopup(popup_650c7b74c272495a6164912352931641)
#         ;
#
#
#
#
#             var marker_0bb85e7c6c91678c169cb33e41994194 = L.marker(
#                 [37.87438, 127.74109],
#                 {}
#             ).addTo(map_54149f2b3214795e5d0055345c7e6d7d);
#
#
#             var icon_c15ed6130509c0af7d8ff08ace23dd3f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&q

# %%
centers
# Out:
# array([[ 37.87382222, 127.74484222],
#        [ 37.86744667, 127.73393333]])

# %%
# 클러스터링 수행
kmeans = KMeans(n_clusters=2, random_state=0).fit(centesrs_man)
labels = kmeans.labels_

# Folium 지도 생성
m = folium.Map(location=[37.87, 127.74], zoom_start=14)

# 클러스터 중심을 지도에 추가
for i, center in enumerate(centers):
    folium.Marker(location=center, popup=f'Center {i+1}', icon=folium.Icon(color='red')).add_to(m)

# 클러스터링된 지점들을 지도에 추가
colors = ['blue', 'green']
for i, (location, label) in enumerate(zip(centesrs_man, labels)):
    folium.Marker(location=location, popup=f'Man {i+1}', icon=folium.Icon(color=colors[label])).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6e88c4868a386ef93c995d30f7e156f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6e88c4868a386ef93c995d30f7e156f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6e88c4868a386ef93c995d30f7e156f = L.map(
#                 &quot;map_a6e88c4868a386ef93c995d30f7e156f&quot;,
#                 {
#                     center: [37.87, 127.74],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_164485962f43ee535f719d79db646e67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_164485962f43ee535f719d79db646e67.addTo(map_a6e88c4868a386ef93c995d30f7e156f);
#
#
#             var marker_8020c9d90b64b9393aa877bec332342f = L.marker(
#                 [37.87382222222222, 127.74484222222222],
#                 {}
#             ).addTo(map_a6e88c4868a386ef93c995d30f7e156f);
#
#
#             var icon_f88de470ae920a482382f4e013dfd363 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8020c9d90b64b9393aa877bec332342f.setIcon(icon_f88de470ae920a482382f4e013dfd363);
#
#
#         var popup_47351429d91905594aee06203c980e0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ffad6a0b35f62e919b4d6ae9a83cc3c = $(`&lt;div id=&quot;html_0ffad6a0b35f62e919b4d6ae9a83cc3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center 1&lt;/div&gt;`)[0];
#                 popup_47351429d91905594aee06203c980e0e.setContent(html_0ffad6a0b35f62e919b4d6ae9a83cc3c);
#
#
#
#         marker_8020c9d90b64b9393aa877bec332342f.bindPopup(popup_47351429d91905594aee06203c980e0e)
#         ;
#
#
#
#
#             var marker_ceec9e151b0517027eb2d034fa967420 = L.marker(
#                 [37.867446666666666, 127.73393333333334],
#                 {}
#             ).addTo(map_a6e88c4868a386ef93c995d30f7e156f);
#
#
#             var icon_457020b542d6d9540a2c12acdb099a1c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ceec9e151b0517027eb2d034fa967420.setIcon(icon_457020b542d6d9540a2c12acdb099a1c);
#
#
#         var popup_df8db7b919ef3bc4fc173379f35623fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b518e549a693b1d20869eed3c66168af = $(`&lt;div id=&quot;html_b518e549a693b1d20869eed3c66168af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Center 2&lt;/div&gt;`)[0];
#                 popup_df8db7b919ef3bc4fc173379f35623fd.setContent(html_b518e549a693b1d20869eed3c66168af);
#
#
#
#         marker_ceec9e151b0517027eb2d034fa967420.bindPopup(popup_df8db7b919ef3bc4fc173379f35623fd)
#         ;
#
#
#
#
#             var marker_575d719f642925aa5ee78f8709b86d73 = L.marker(
#                 [37.869980827946165, 127.72886894913997],
#                 {}
#             ).addTo(map_a6e88c4868a386ef93c995d30f7e156f);
#
#
#             var icon_ec54a78f26883aede86218c4ead28c37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_575d719f642925aa5ee78f8709b86d73.setIcon(icon_ec54a78f26883aede86218c4ead28c37);
#
#
#         var popup_f90096328e01868e796a756fb3a1ecb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_403cc1757277fb83dcaa868de8c23653 = $(`&lt;div id=&quot;html_403cc1757277fb83dcaa868de8c23653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Man 1&lt;/div&gt;`)[0];
#                 popup_f90096328e01868e796a756fb3a1ecb4.setContent(html_403cc1757277fb83dcaa868de8c23653);
#
#
#
#         marker_575d719f642925aa5ee78f8709b86d73.bindPopup(popup_f90096328e01868e796a756fb3a1ecb4)
#         ;
#
#
#
#
#             var marker_6356d0e1bebcc677b21c101df8d549c9 = L.marker(
#                 [37.87593180659868, 127.73722463539664],
#                 {}
#             ).addTo(map_a6e88c4868a386ef93c995d30f7e156f);
#
#
#             var icon_ee1061afcaffd79361bb0a9e2bb228f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;ico

# %%
from sklearn.cluster import KMeans
import folium

# K-means 클러스터링 수행
k = 2  # 클러스터의 수 (임의로 지정)
coordinates = df_combined[['위도', '경도']]
kmeans = KMeans(n_clusters=k, random_state=0).fit(coordinates)
centers = kmeans.cluster_centers_

# Folium 지도 생성
map_center = [df_combined['위도'].mean(), df_combined['경도'].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# 클러스터 중심 위치 표시
for center in centers:
    folium.Marker(
        location=[center[0], center[1]],
        popup="클러스터 중심",
        icon=folium.Icon(color='black', icon='info-sign')
    ).add_to(mymap)

# 다른 위치 정보 추가
for index, row in df_combined.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=row['정류장명'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(mymap)

# 지도 출력
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b71a4df39e251b02f861b94c959de1f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b71a4df39e251b02f861b94c959de1f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b71a4df39e251b02f861b94c959de1f9 = L.map(
#                 &quot;map_b71a4df39e251b02f861b94c959de1f9&quot;,
#                 {
#                     center: [37.87222833333333, 127.74211500000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb6439b14d333fb1fa4705e1dd99c617 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb6439b14d333fb1fa4705e1dd99c617.addTo(map_b71a4df39e251b02f861b94c959de1f9);
#
#
#             var marker_c8c78828f03cd259cbf6ef1e668609f1 = L.marker(
#                 [37.87382222222222, 127.74484222222222],
#                 {}
#             ).addTo(map_b71a4df39e251b02f861b94c959de1f9);
#
#
#             var icon_1648aceec6601d6fcd3e8280ba8eae09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c8c78828f03cd259cbf6ef1e668609f1.setIcon(icon_1648aceec6601d6fcd3e8280ba8eae09);
#
#
#         var popup_4c96bd07263f9308238e12a8dc7eff90 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c09e5b3a43e928b5f7bd467c97d3dde = $(`&lt;div id=&quot;html_6c09e5b3a43e928b5f7bd467c97d3dde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;클러스터 중심&lt;/div&gt;`)[0];
#                 popup_4c96bd07263f9308238e12a8dc7eff90.setContent(html_6c09e5b3a43e928b5f7bd467c97d3dde);
#
#
#
#         marker_c8c78828f03cd259cbf6ef1e668609f1.bindPopup(popup_4c96bd07263f9308238e12a8dc7eff90)
#         ;
#
#
#
#
#             var marker_d7fee7811cc73a9de0929e3f88cbb3ee = L.marker(
#                 [37.867446666666666, 127.73393333333334],
#                 {}
#             ).addTo(map_b71a4df39e251b02f861b94c959de1f9);
#
#
#             var icon_64b0ce44c1a4c753872256f81581fba3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7fee7811cc73a9de0929e3f88cbb3ee.setIcon(icon_64b0ce44c1a4c753872256f81581fba3);
#
#
#         var popup_4069c449827778f6963945a0fafab518 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82467930c7dca101a2686f3749672a34 = $(`&lt;div id=&quot;html_82467930c7dca101a2686f3749672a34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;클러스터 중심&lt;/div&gt;`)[0];
#                 popup_4069c449827778f6963945a0fafab518.setContent(html_82467930c7dca101a2686f3749672a34);
#
#
#
#         marker_d7fee7811cc73a9de0929e3f88cbb3ee.bindPopup(popup_4069c449827778f6963945a0fafab518)
#         ;
#
#
#
#
#             var marker_335184f9044df02a6516d82631ed01e0 = L.marker(
#                 [37.87735, 127.74822],
#                 {}
#             ).addTo(map_b71a4df39e251b02f861b94c959de1f9);
#
#
#             var icon_b4c1a28d76d87f0350decc60a0a75b0a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_335184f9044df02a6516d82631ed01e0.setIcon(icon_b4c1a28d76d87f0350decc60a0a75b0a);
#
#
#         var popup_ae692dd82443ece2cb77632b68888b0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1d03a2febb98133a55db62c583332c78 = $(`&lt;div id=&quot;html_1d03a2febb98133a55db62c583332c78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;일성트루엘A&lt;/div&gt;`)[0];
#                 popup_ae692dd82443ece2cb77632b68888b0b.setContent(html_1d03a2febb98133a55db62c583332c78);
#
#
#
#         marker_335184f9044df02a6516d82631ed01e0.bindPopup(popup_ae692dd82443ece2cb77632b68888b0b)
#         ;
#
#
#
#
#             var marker_2dddca84d5cadeea340467e3eb4a4a51 = L.marker(
#                 [37.87622, 127.74556],
#                 {}
#             ).addTo(map_b71a4df39e251b02f861b94c959de1f9);
#
#
#             var icon_2e7facc2771879e4b7331bec8b172d0c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot

# %%
# KMeans 클러스터링 수행
kmeans = KMeans(n_clusters=2, random_state=0).fit(centers_man)
labels = kmeans.labels_

# Folium 지도 생성
map_center = [centers_man[:, 0].mean(), centers_man[:, 1].mean()]
mymap = folium.Map(location=map_center, zoom_start=14)

# 클러스터 중심을 지도에 추가
for i, center in enumerate(centers):
    folium.CircleMarker(
        location=center,
        radius=10,
        color='red',
        fill=True,
        fill_color='red',
        popup=f'클러스터 중심 {i+1}'
    ).add_to(mymap)

# 클러스터링된 지점들을 지도에 추가
colors = ['blue', 'green']
for i, (location, label) in enumerate(zip(centers_man, labels)):
    folium.CircleMarker(
        location=location,
        radius=5,
        color=colors[label],
        fill=True,
        fill_color=colors[label],
        popup=f'지점 {i+1}'
    ).add_to(mymap)

# 지도 출력 (주피터 노트북이나 IPython 환경에서)
mymap
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # KMeans 클러스터링 수행
# ----> 2 kmeans = KMeans(n_clusters=2, random_state=0).fit(centers_man)
#       3 labels = kmeans.labels_
#       5 # Folium 지도 생성
#
# NameError: name 'centers_man' is not defined

# %%
centers
# Out:
# array([[ 37.87382222, 127.74484222],
#        [ 37.86744667, 127.73393333]])

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# SSE(Sum of Squared Errors)를 계산하는 함수
def calculate_sse(data, k_range):
    sse = []
    for k in k_range:
        kmeans = KMeans(n_clusters=k, random_state=0).fit(data)
        sse.append(kmeans.inertia_)
    return sse

# K의 범위 설정
k_range = range(1, 5)  # 1부터 4까지의 클러스터 개수를 시도
  # 1부터 10까지의 클러스터 개수를 시도

# SSE 계산
sse = calculate_sse(coordinates, k_range)

# Elbow Method 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(k_range, sse, marker='o', linestyle='-')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.xticks(k_range)
plt.grid(True)
plt.show()
